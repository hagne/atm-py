# %%
import atmPy.data_archives.nasa.merra2 as atmmerra

# %%
reload(atmmerra)
# Out:
# <module 'atmPy.data_archives.nasa.merra2' from '/Users/htelg/prog/atm-py/atmPy/data_archives/nasa/merra2.py'>

# %%
mi = atmmerra.Merra2()

# %%
ds = mi.download_total_column_ozone('2026-05-13','2026-05-13', backend = 'harmony')
# Out:
#  [ Processing:   0% ] |                                                   | [/]
#  [ Processing:   0% ] |                                                   | [-]
#  [ Processing:   0% ] |                                                   | [\]
#  [ Processing:   0% ] |                                                   | [|]
#  [ Processing:   0% ] |                                                   | [/]
#  [ Processing:   0% ] |                                                   | [-]
#  [ Processing:   0% ] |                                                   | [\]
#  [ Processing:   0% ] |                                                   | [|]
#  [ Processing:   0% ] |                                                   | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
# ...

# %%
ds.TO3.interp(lat = 43.594919, lon = -112.928561).plot()

# %%
ds
# Out:
# <xarray.Dataset> Size: 20MB
# Dimensions:   (datetime: 24, lat: 361, lon: 576)
# Coordinates:
#   * datetime  (datetime) datetime64[ns] 192B 2026-05-13T00:30:00 ... 2026-05-...
#   * lat       (lat) float64 3kB -90.0 -89.5 -89.0 -88.5 ... 88.5 89.0 89.5 90.0
#   * lon       (lon) float64 5kB -180.0 -179.4 -178.8 ... 178.1 178.8 179.4
# Data variables:
#     TO3       (datetime, lat, lon) float32 20MB dask.array<chunksize=(24, 361, 576), meta=np.ndarray>
# Attributes: (12/38)
#     DODS_EXTRA.Unlimited_Dimension:    time
#     History:                           Original file generated: Sat May 23 20...
#     Comment:                           GMAO filename: d5124_m2_jan10.tavg1_2d...
#     Filename:                          MERRA2_400.tavg1_2d_slv_Nx.20260513.nc4
#     Conventions:                       CF-1
#     Institution:                       NASA Global Modeling and Assimilation ...
#     ...                                ...
# ...

# %%
ds.TO3.isel(datetime = 0).plot()
