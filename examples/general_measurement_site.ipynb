# %%
plt.rcParams['figure.dpi'] = 200

# %%
import atmPy.general.measurement_site as atmsite

# %% [markdown]
# # Station instance

# %%
site = atmsite.Station(
    lat=40.12498,
    lon=-105.23680,
    alt=None,
    name='Table Mountain',
    abbreviation='TBL',
    active=None,
    operation_period=None,
    info=None,
    state='',
    country='',
    parent_network=None,
    )

# %% [markdown]
# ## plot on map

# %%
site.plot()
# Out:
# (<Figure size 1280x960 with 1 Axes>, <GeoAxes: >)

# %% [markdown]
# ## get solar information for given time at that location

# %%
dt = pd.date_range(start = '20250101', end = '20250102', freq='h')

# %%
site.get_sun_position(dt)
# Out:
# <xarray.Dataset> Size: 2kB
# Dimensions:             (datetime: 25)
# Coordinates:
#   * datetime            (datetime) datetime64[us] 200B 2025-01-01 ... 2025-01-02
# Data variables:
#     zenith              (datetime) float64 200B 1.628 1.811 ... 1.455 1.625
#     zenith_geometric    (datetime) float64 200B 1.628 1.811 ... 1.457 1.625
#     apparent_elevation  (datetime) float64 200B -0.0567 -0.2406 ... -0.05429
#     elevation           (datetime) float64 200B -0.0567 -0.2406 ... -0.05429
#     azimuth             (datetime) float64 200B 4.23 4.387 4.539 ... 4.057 4.23
#     equation_of_time    (datetime) float64 200B -3.439 -3.459 ... -3.89 -3.909
#     airmass             (datetime) float64 200B nan nan nan ... 3.822 8.086 nan
#     airmass_absolute    (datetime) float64 200B nan nan nan ... 3.099 6.556 nan
#     sun_earth_distance  (datetime) float64 200B 0.9834 0.9834 ... 0.9833 0.9833
# Attributes:
#     Conventions:  CF-1.13
# ...

# %% [markdown]
# # Network and NetworkStations (TODO: add content)

# %%
atmsite.Network()
