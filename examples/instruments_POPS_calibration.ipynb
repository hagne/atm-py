# %%
from atmPy.aerosols.instruments.POPS import calibration
from atmPy.tools import plt_tools
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# # Generate a theoretical calibration

# %% [markdown]
# One can generate a calibration file based on the theoretical responds of the POPS instrument and a single point calibration.

# %%
reload(calibration)
# Out:
# <module 'atmPy.aerosols.instruments.POPS.calibration' from '/home/grad/htelg/prog_dev/atm-py/atmPy/aerosols/instruments/POPS/calibration.py'>

# %%
cal = calibration.generate_calibration(
    single_pnt_cali_d=508,
    single_pnt_cali_ior=1.6,
    single_pnt_cali_int=1000,
    noise_level = 12,
    ior=1.4,
    dr=[100, 5000],
    no_pts=500,
    no_cal_pts=60,
    plot=True,
    raise_error=True,
    test=False,
)

# %% [markdown]
# # Generate an experimental calibration

# %% [markdown]
# This section shows how to read and save calibration data. In the process the data will be fit and a calibration function is created. Data and function can be plotted using the plot function mentioned below.

# %% [markdown]
# ## read from string

# %% [markdown]
# create a string where each line consist of a diameter value (in nm) and an amplitude (in digitizer bin) seperated by space. <br> Note, in the example below the secend column is the $log_{10}(amplitude)$. The following cell does the convertion!

# %%
reload(calibration)
# Out:
# <module 'atmPy.aerosols.instruments.POPS.calibration' from '/home/grad/htelg/prog_dev/atm-py/atmPy/aerosols/instruments/POPS/calibration.py'>

# %%
data = """130 1.73
140 1.85
150 1.99
173 2.28
200 2.53
233 2.77
270 2.96
315 3.04
365 3.165
420 3.213
490 3.355
570 3.56
660 3.72
770 3.795
890 3.86
1040 4.0
1200 4.05
1400 4.1
1600 4.18
1880 4.32
2180 4.44
2500 4.5"""

# %%
cal = calibration.read_str(data)

# %%
cal.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Calibration curve'}, xlabel='Diameter (nm)', ylabel='Amplitude (digitizer bins)'>,
#  <matplotlib.lines.Line2D at 0x7f64be8f4710>,
#  <matplotlib.lines.Line2D at 0x7f64be80c490>)

# %% [markdown]
# ## Save the calibration from above

# %%
fname = './data/POPS_calibration.csv'
cal.save_csv(fname)

# %% [markdown]
# ## read the file we just saved

# %%
out = calibration.read_csv(fname)

# %% [markdown]
# # plot the created calibration function and data

# %%
f,a,df,gf = cal.plot()

# %% [markdown]
# # Translate intensity bins to diameters

# %% [markdown]
# This information is necessarey if data is provided prebinned e.g. when recorded through the serial interface.

# %%
out = calibration.get_interface_bins('/Users/htelg/data/POPS_calibrations/150529_MS1_DOS.csv', 16)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 out = calibration.get_interface_bins('/Users/htelg/data/POPS_calibrations/150529_MS1_DOS.csv', 16)
#
# File ~/prog_dev/atm-py/atmPy/aerosols/instruments/POPS/calibration.py:274, in get_interface_bins(fname, n_bins, imin, imax, save, verbose)
#     252 """Prints the bins assosiated with what is seen on the POPS user interface and the serial output, respectively.
#     253
#     254 Parameters
#    (...)
#     271 pandas DataFrame instance
#     272 """
#     273 if isinstance(fname, str):
# --> 274     cal = read_csv(fname)
#     275 else:
#     276     cal = fname
#
# File ~/prog_dev/atm-py/atmPy/aerosols/instruments/POPS/calibration.py:422, in read_csv(fname)
#     420 def read_csv(fname):
#     421     """ most likely found here"""
# --> 422     calDataFrame = pd.read_csv(fname)
#     423     calibrationInstance = Calibration(calDataFrame)
#     424     return calibrationInstance
#
# File /export2/htelg/programs/miniconda3/envs/py11t2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /export2/htelg/programs/miniconda3/envs/py11t2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /export2/htelg/programs/miniconda3/envs/py11t2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /export2/htelg/programs/miniconda3/envs/py11t2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /export2/htelg/programs/miniconda3/envs/py11t2/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/htelg/data/POPS_calibrations/150529_MS1_DOS.csv'

# %%
out = calibration.get_interface_bins('/Users/htelg/data/POPS_calibrations/150529_MS1_DOS.csv', 16)
# Out:
# bin edges (digitizer bins)
# --------------------------
# 25.1188643151
# 40.9732109814
# 66.8343917569
# 109.018449239
# 177.827941004
# 290.068119869
# 473.151258961
# 771.791515585
# 1258.92541179
# 2053.52502646
# 3349.65439158
# 5463.86549882
# 8912.50938134
# 14537.8438561
# 23713.7370566
# 38681.2054633
# 63095.734448
#
# bin centers (digitizer bins)
# ----------------------------
# 33.0460376482
# 53.9038013691
# 87.9264204977
# 143.423195121
# 233.948030437
# 381.609689415
# 622.471387273
# 1015.35846369
# 1656.22521913
# 2701.58970902
# 4406.7599452
# 7188.18744008
# 11725.1766187
# 19125.7904563
# 31197.47126
# 50888.4699557
#
# bin centers of logarithms (digitizer bins)
# ----------------------------
# 32.0811553282
# 52.3299114681
# 85.3591339291
# 139.23550682
# 227.117186728
# 370.467402211
# 604.296390238
# 985.711900901
# 1607.86654905
# 2622.70835647
# 4278.09081988
# 6978.3058486
# 11382.8234525
# 18567.3532463
# 30286.5636114
# 49402.6220766
#
#
# bin edges (nm)
# --------------
# -13123.6305447
# 46.6840431939
# 142.571641329
# 159.767885528
# 180.088512944
# 203.671751733
# 231.442555915
# 278.203954665
# 365.079142428
# 503.584688239
# 594.171276073
# 766.230032055
# 1074.28311815
# 1688.60408594
# 2138.35179782
# 2864.23372769
# 5130.89339925
#
# bin centers (nm)
# ----------------
# -2561.44444891
# 134.554568952
# 151.969566777
# 170.665148909
# 193.010367613
# 218.190007849
# 253.014866483
# 324.659905185
# 460.571745708
# 551.637033828
# 666.96398972
# 940.939314753
# 1487.84671117
# 1932.77239747
# 2479.59889885
# 3719.97365794
#
# bin centers of logarithms (nm)
# ----------------
# -3309.42962297
# 133.362308214
# 150.931399559
# 169.42416447
# 191.575385102
# 216.53506681
# 250.309341542
# 319.830164546
# 453.185397003
# 546.293397888
# 657.293127812
# 926.222022082
# 1456.83312689
# 1906.16034672
# 2436.31185743
# 3592.45946861
