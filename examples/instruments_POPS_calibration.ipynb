# %%
from atmPy.aerosols.instruments.POPS import calibration
from atmPy.tools import plt_tools
import numpy as np

# %%
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# # (baustelle) Generate a theoretical calibration

# %%
from atmPy.aerosols.instruments.POPS import mie as pm

# %%
ns = np.linspace(1.5,2.95,3)
ns = [2.]

f,a = plt.subplots()
a.loglog()
for n in ns:
    d,mie = pm.makeMie_diameter(IOR = n)
    g, = a.plot(d,mie, label = n)
#     g.set_linestyle('')
#     g.set_marker('.')
a.legend()

# %%
# %%time
n = 2.95
d,mie = pm.makeMie_diameter(diameterRangeInMikroMeter=[0.1, 5.0],  
                            noOfdiameters=1e4,
                            IOR = n)
df = pd.DataFrame({'d':d, 'mie':mie})
# Out:
# CPU times: user 27.5 s, sys: 15.4 ms, total: 27.5 s
# Wall time: 27.5 s

# %%
# %%time
nofbins = 50
valid = False
while not valid:
    nofbins -= 1
    binedgs = np.logspace(np.log10(mie.min()), np.log10(mie.max()), nofbins)
    binedgs[0] -= (binedgs[1] - binedgs[0]) * 0.01 # this is to ensure the first point is not onthe edge ... for cut function used later


    dfavg = df.groupby(pd.cut(df.mie, binedgs)).median()
    dfstd = df.groupby(pd.cut(df.mie, binedgs)).mad()
    dfavg.index.name = None
    # dfbined

    dfavg.sort_values('mie', axis=0, inplace=True)
    if not ((dfavg.d.values[1:] - dfavg.d.values[:-1]) < 0).sum():
        valid = True
if 0:
    a = df.mie.hist(bins = dfavg)
    a.semilogx()
nofbins
# Out:
# 14

# %%
f,a = plt.subplots()
g, = a.plot(d,mie, label = n)
g.set_linestyle('')
g.set_marker('.')
g.set_markersize(1)

#print binedges
if 1:
    for be in binedgs:
        out = a.axhline(be)
        out.set_linestyle(':')
        out.set_linewidth(1)
        out.set_color('0.5')
        
#print averaged data
if 1:
#     a.plot(dfavg.d, dfavg.mie)
    a.errorbar(dfavg.d, dfavg.mie, xerr=dfstd.d, yerr=dfstd.mie, zorder = 10)
a.legend()
a.loglog()
# Out:
# []

# %%
df.shape bide
# Out:
# (200, 2)

# %%
df.mie.mod(binedgs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-0f6a614f9cd6> in <module>
# ----> 1 df.mie.mod(binedgs)
#
# /mnt/telg/programs/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in flex_wrapper(self, other, level, fill_value, axis)
#    1341         elif isinstance(other, (np.ndarray, list, tuple)):
#    1342             if len(other) != len(self):
# -> 1343                 raise ValueError("Lengths must be equal")
#    1344             other = self._constructor(other, self.index)
#    1345             return self._binop(other, op, level=level, fill_value=fill_value)
#
# ValueError: Lengths must be equal

# %% [markdown]
# One can generate a calibration file based on the theoretical responds of the POPS instrument and a single point calibration.

# %%
cali, a = calibration.generate_calibration(single_pnt_cali_d = 510,
                                             single_pnt_cali_ior = 1.6,
                                             single_pnt_cali_int = 10**3.508,
                                             ior = 1.7,
                                             dr=np.array([110, 3400]),
                                             no_pts = 600,
                                             no_cal_pts = 29,
                                             plot = True,
                                             raise_error = True,
                                             test = False
                                            )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-a280710a04b9> in <module>
#       8                                              plot = True,
#       9                                              raise_error = True,
# ---> 10                                              test = False
#      11                                             )
#
# /mnt/telg/prog/atm-py/atmPy/aerosols/instruments/POPS/calibration.py in generate_calibration(single_pnt_cali_d, single_pnt_cali_ior, single_pnt_cali_int, ior, dr, no_pts, no_cal_pts, plot, raise_error, test)
#     101     cali_inst = pd.DataFrame(cali, columns=['amp'])
#     102     cali_inst['d'] = cali_inst.index
# --> 103     cali_inst = Calibration(cali_inst)
#     104
#     105     if raise_error:
#
# /mnt/telg/prog/atm-py/atmPy/aerosols/instruments/POPS/calibration.py in __init__(self, dataTabel)
#     318     def __init__(self,dataTabel):
#     319         self.data = dataTabel
# --> 320         self.calibrationFunction = self.get_calibrationFunctionSpline()
#     321
#     322     def get_interface_bins(self, n_bins, imin=1.4, imax=4.8, save=False, verbose = False):
#
# /mnt/telg/prog/atm-py/atmPy/aerosols/instruments/POPS/calibration.py in get_calibrationFunctionSpline(self, fitOrder)
#     364
#     365         # us = UnivariateSpline(np.log10(self.data.amp), np.log10(self.data.d), s=0)
# --> 366         us = UnivariateSpline(amp, d, s=0)
#     367         cal_function = lambda amp: 10**us(np.log10(amp))
#     368         return cal_function
#
# /mnt/telg/programs/anaconda3/lib/python3.7/site-packages/scipy/interpolate/fitpack2.py in __init__(self, x, y, w, bbox, k, s, ext, check_finite)
#     175                                  "NaNs or infs.")
#     176         if not np.all(diff(x) > 0.0):
# --> 177             raise ValueError('x must be strictly increasing')
#     178
#     179         # _data == x,y,w,xb,xe,k,s,n,t,c,fp,fpint,nrdata,ier
#
# ValueError: x must be strictly increasing

# %%
cali.plot_calibration()
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc998986dd8>,
#  <matplotlib.lines.Line2D at 0x7fc9988777b8>,
#  <matplotlib.lines.Line2D at 0x7fc998250ba8>)

# %% [markdown]
# # Generate a theoretical calibration

# %% [markdown]
# One can generate a calibration file based on the theoretical responds of the POPS instrument and a single point calibration.

# %%
cali, a = calibration.generate_calibration(single_pnt_cali_d = 510,
                                             single_pnt_cali_ior = 1.6,
                                             single_pnt_cali_int = 10**3.508,
                                             ior = 1.5,
                                             dr=np.array([110, 3400]),
                                             no_pts = 600,
                                             no_cal_pts = 30,
                                             plot = True,
                                             raise_error = True,
                                             test = False
                                            )

# %%
cali.plot_calibration()
# Out:
# (<matplotlib.figure.Figure at 0x10d7aea20>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10d71d630>,
#  <matplotlib.lines.Line2D at 0x10d893400>,
#  <matplotlib.lines.Line2D at 0x10d893f98>)

# %% [markdown]
# # Generate an experimental calibration

# %% [markdown]
# This section shows how to read and save calibration data. In the process the data will be fit and a calibration function is created. Data and function can be plotted using the plot function mentioned below.

# %% [markdown]
# ## read from string

# %% [markdown]
# create a string where each line consist of a diameter value (in nm) and an amplitude (in digitizer bin) seperated by space. <br> Note, in the example below the secend column is the $log_{10}(amplitude)$. The following cell does the convertion!

# %%
data = """130 1.73
140 1.85
150 1.99
173 2.28
200 2.53
233 2.77
270 2.96
315 3.04
365 3.165
420 3.213
490 3.355
570 3.56
660 3.72
770 3.795
890 3.86
1040 4.0
1200 4.05
1400 4.1
1600 4.18
1880 4.32
2180 4.44
2500 4.5"""

# %%
cal = calibration.read_str(data)
# Out:
# /Users/htelg/prog/atm-py/atmPy/instruments/POPS/calibration.py:140: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dataFrame = pd.read_csv(sb, sep = ' ', names = ('d','amp')).sort('d')

# %% [markdown]
# ## Save the calibration from above

# %%
fname = './data/POPS_calibration.csv'
cal.save_csv(fname)

# %% [markdown]
# ## read the file we just saved

# %%
out = calibration.read_csv(fname)

# %% [markdown]
# # plot the created calibration function and data

# %%
f,a,df,gf = cal.plot_calibration()

# %% [markdown]
# # Translate bins to diameters

# %% [markdown]
# This information is necessarey if data is provided prebinned e.g. when recorded through the serial interface.

# %%
out = calibration.get_interface_bins('/Users/htelg/data/POPS_calibrations/150529_MS1_DOS.csv', 16)
# Out:
# bin edges (digitizer bins)
# --------------------------
# 25.1188643151
# 40.9732109814
# 66.8343917569
# 109.018449239
# 177.827941004
# 290.068119869
# 473.151258961
# 771.791515585
# 1258.92541179
# 2053.52502646
# 3349.65439158
# 5463.86549882
# 8912.50938134
# 14537.8438561
# 23713.7370566
# 38681.2054633
# 63095.734448
#
# bin centers (digitizer bins)
# ----------------------------
# 33.0460376482
# 53.9038013691
# 87.9264204977
# 143.423195121
# 233.948030437
# 381.609689415
# 622.471387273
# 1015.35846369
# 1656.22521913
# 2701.58970902
# 4406.7599452
# 7188.18744008
# 11725.1766187
# 19125.7904563
# 31197.47126
# 50888.4699557
#
# bin centers of logarithms (digitizer bins)
# ----------------------------
# 32.0811553282
# 52.3299114681
# 85.3591339291
# 139.23550682
# 227.117186728
# 370.467402211
# 604.296390238
# 985.711900901
# 1607.86654905
# 2622.70835647
# 4278.09081988
# 6978.3058486
# 11382.8234525
# 18567.3532463
# 30286.5636114
# 49402.6220766
#
#
# bin edges (nm)
# --------------
# -13123.6305447
# 46.6840431939
# 142.571641329
# 159.767885528
# 180.088512944
# 203.671751733
# 231.442555915
# 278.203954665
# 365.079142428
# 503.584688239
# 594.171276073
# 766.230032055
# 1074.28311815
# 1688.60408594
# 2138.35179782
# 2864.23372769
# 5130.89339925
#
# bin centers (nm)
# ----------------
# -2561.44444891
# 134.554568952
# 151.969566777
# 170.665148909
# 193.010367613
# 218.190007849
# 253.014866483
# 324.659905185
# 460.571745708
# 551.637033828
# 666.96398972
# 940.939314753
# 1487.84671117
# 1932.77239747
# 2479.59889885
# 3719.97365794
#
# bin centers of logarithms (nm)
# ----------------
# -3309.42962297
# 133.362308214
# 150.931399559
# 169.42416447
# 191.575385102
# 216.53506681
# 250.309341542
# 319.830164546
# 453.185397003
# 546.293397888
# 657.293127812
# 926.222022082
# 1456.83312689
# 1906.16034672
# 2436.31185743
# 3592.45946861
